# %%
import numpy as np
import matplotlib.ptplot as plt

#generate synthetic data
ddef generate_data(n_samples=300,n_centers=4,random_seed=42):
np.random.seed(ramdom_seed)
points_per_senter=n_samples
centers=np.random.uniform(-10,10,(n_centers,2))
X=np.vstack([center+np.random.randn(points_per_center,2)for center in center])
return X
#calculate Euclidean distance
def euclidean_distance(a,b):
  return np.sqrt(np.sum((a-b)**2))
#compute the distance matrix
def compute_distance_matrix (X)
n_samples+X.shape[0]
distances+np.zeros((n_samples,n_samples))
for i in range(n_samples):
  for j in range(n_samples):
    distances[i,j]=euclidean_distance(X[i],X[j])
    distances[j,i]=distances[i,j]
    return distances
#hierarchical Clustering
def hierarchical_clustering(X)
distances=compute_distance_matrix(X)
n_samples=len(X)
#initial clusters
clusters=[[i] for i in range(n_samples)]
while len(clusters)>1
#find the two closest clusters
min_dist=float('inf')
to_merge=(None,None)
for i in range(len(clusters)):
  for j in range(i+1,len(clusters)):
    d=np.min([distances[p][q] for p in clusters[i] for q in clusters[j]])
    if d<min_dist:
      min_dist=d
      to_merge=(i,j)
#merge the two closest clusters
i,j=to_merge
clusters[i].extend(clusters[j])
del clusters[j]
return clusters
#function to extract cluster labels
def extract_clusters(clusters,n_samples):
  labels=np.zeros(n_samples)
  for cluster_id,cluster in enumerate(clusters):
    for index in cluster:
      labels[np.inexact]
# Out:
#   File "/tmp/ipython-input-1600820340.py", line 5
#     ddef generate_data(n_samples=300,n_centers=4,random_seed=42):
#          ^
# SyntaxError: invalid syntax

# %%
_
